# %%
import gym
import numpy as np
from stable_baselines3 import A2C, DDPG, SAC, PPO
from matplotlib import axis
import numpy as np
from floris.tools import FlorisInterface
from floris.tools.visualization import visualize_cut_plane
import matplotlib.pyplot as plt
from floris.tools.optimization.yaw_optimization.yaw_optimizer_sr import YawOptimizationSR

from gym import spaces

from stable_baselines3.common.env_checker import check_env
import os
import time
from tqdm import tqdm_notebook
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.callbacks import BaseCallback

from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.utils import set_random_seed

from matplotlib.pyplot import figure

#loading optimization package:
from scipy.optimize import minimize

from floris.tools.optimization.yaw_optimization.yaw_optimizer_scipy import (
    YawOptimizationScipy
)

from time import perf_counter as timerpc

import yaml
import math
from scipy import interpolate

# %%
class CustomEnv(gym.Env):
    """
    The inputs are:
    t_steps     = number of timesteps pr simulation
    dist        ª= rotor diameters between the turbines
    nx          = number of turbines along x axis
    ny          = number of turbines along y axis
    turb_type   = The type of turbine used for the environment
    combination = The combination model
    deflection  = The deflection model
    turbulence  = The turbulence model
    velocity    = The wake velocity model
    VS_min      = minimum wind speed [m/s]
    VS_max      = maximum wind speed [m/s]
    TI_min      = minimum turbulence intensity
    TI_max      = maximum turbulence intensity
    wd_min      = minimum wind direction
    wd_max      = maximum wind direction
    yaw_max     = Is the maximum yaw offset allowed in degrees.
    
    """
    #Custom Environment that follows gym interface
    metadata = {'render.modes': ['human']}

    def __init__(self, t_steps = 10, dist = 5, nx = 3, ny = 3,
               turb_type = 'nrel_5MW', combination = 'sosfs', deflection = 'gauss',
               turbulence = 'crespo_hernandez', velocity = 'gauss',
               VS_min = 4, VS_max = 20, TI_min = 0.01, TI_max = 0.15, wd_min = 270, wd_max = 360, 
               yaw_max = 25, rho = 1.225):
        super(CustomEnv, self).__init__()
        
        self.t_max = t_steps   #The number of "simulations" pr episode.
        self.wind_speed_min = VS_min
        self.wind_speed_max = VS_max
        self.TI_min         = TI_min
        self.TI_max         = TI_max
        self.wd_min         = wd_min
        self.wd_max         = wd_max
        self.n_turb         = nx * ny
        self.yaw_max        = yaw_max
        self.rho            = rho
                     
        #Creates the base for the farm
        fi = FlorisInterface("gch.yaml")   
        
        #Turns it into a dictionary and then does the changes to the model
        fi_dict = fi.floris.as_dict()
        
        fi_dict["farm"]["turbine_type"] = [turb_type]
        fi_dict["wake"]["model_strings"]["combination_model"] = combination
        fi_dict["wake"]["model_strings"]["deflection_model"]  = deflection
        fi_dict["wake"]["model_strings"]["turbulence_model"]  = turbulence
        fi_dict["wake"]["model_strings"]["velocity_model"]    = velocity
        fi_dict["flow_field"]["air_density"]                  = rho
        
        # Turns it back into a floris object:
        self.fi = FlorisInterface(fi_dict)

        D = self.fi.floris.farm.rotor_diameters[0]

        x = np.linspace(0, D*dist*nx, nx)
        y = np.linspace(0, D*dist*ny, ny)

        xv, yv = np.meshgrid(x, y, indexing='xy')
        
        self.layout_x =  xv.flatten()
        self.layout_y = yv.flatten()
        
        #Reads and saves the power curve for one turbine:
        
        with open(turb_type+".yaml", 'r') as stream:
            try:
                parsed_yaml=yaml.safe_load(stream)
                #print(parsed_yaml)
            except yaml.YAMLError as exc:
                print(exc)

        ws_curve = parsed_yaml["power_thrust_table"]["wind_speed"]
        power_curve = parsed_yaml["power_thrust_table"]["power"]
        
        self.A = 3.14 * (D/2)**2
        self.power_curve = interpolate.interp1d(ws_curve, power_curve)
        

        # Define action and observation space
        
        # The actionspace is the 9 yaw angles.
        self.action_space = spaces.Box(low=-1, high=1,
                                            shape=(nx*ny,), dtype=np.float32)
        
        # The observationspace is WS, TI, WD:
        high = np.array([self.wind_speed_max, self.TI_max, self.wd_max], dtype = np.float32)
        low = np.array([self.wind_speed_min, self.TI_min, self.wd_min], dtype = np.float32)
        
        self.observation_space = spaces.Box(low, high, dtype=np.float32)

        self.reset()
        
    def step(self, action):
        #print("we did a step")
        if self.time > self.t_max:
            done =  True
        else:
            self.time += 1
            done = False
            
        self.fi.calculate_wake(yaw_angles=np.array([[action]]))  #weird format, but it's okay
        
        power_farm = self.fi.get_farm_power()
        
        #Choose if you want ideal farm, or greedy farm for reward calculation.
        #rew = self.fi.get_farm_power()/self.power_ideal_farm
        rew = self.fi.get_farm_power()/self.power_greey_farm
        
        reward = (rew[0][0]-1)*100   #We do this to only return a scalar insted of a array. It maybe doenst like that
            
        info = {}
        observation = np.array([self.ws, self.TI, self.wd], dtype = np.float32)
        return observation, reward, done, info
    
    def reset(self):
        
        #
        self.ws = np.random.uniform(self.wind_speed_min, self.wind_speed_max)
        self.wd = np.random.uniform(self.wd_min, self.wd_max)
        self.TI = np.random.uniform(self.TI_min, self.TI_max)
        

        
        self.fi.reinitialize(
            layout=(self.layout_x, self.layout_y),
            wind_directions=[self.wd],
            turbulence_intensity= self.TI,
            wind_speeds=[self.ws]
            )
        
        
        #Calculate greedy power. Used for normalization
        self.fi.calculate_wake()
        self.power_greey_farm = self.fi.get_farm_power()
        
        #calculate the power for the ideal farm. Used for normalization
        self.power_ideal_farm = self.power_curve(self.ws)*self.n_turb* (1/2) * self.rho * self.A * self.ws**3
        
        self.time = 0
        done = False
        
        observation = np.array([self.ws, self.TI, self.wd], dtype = np.float32)
        return observation  # reward, done, info can't be included
    
    def render(self, mode='human'):
        pass
    
    def close (self):
        pass

# %%
env = CustomEnv(t_steps = 10, dist = 5, nx = 3, ny = 3,
               turb_type = 'nrel_5MW', combination = 'sosfs', deflection = 'gauss',
               turbulence = 'crespo_hernandez', velocity = 'gauss',
               VS_min = 4, VS_max = 20, TI_min = 0.01, TI_max = 0.15, wd_min = 270, wd_max = 270, 
               yaw_max = 25, rho = 1.225)

# %%
check_env(env)

# %%
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log='logs')
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
models_dir = "models/PPO"
log_dir = "logs"

if not os.path.exists(models_dir):
    os.makedirs(models_dir)
    
if not os.path.exists(log_dir):
    os.makedirs(log_dir)

# %%
TIMESTEPS = 50_000

for i in range(1,100):
    model.learn(total_timesteps = TIMESTEPS, reset_num_timesteps = False, tb_log_name="PPO1")
    model.save(f"{models_dir}/{TIMESTEPS*i}")
# Out:
# Logging to logs/PPO1_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 0.2      |
# | time/              |          |
# |    fps             | 77       |
# |    iterations      | 1        |
# |    time_elapsed    | 26       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.102       |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 2           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009116381 |
# |    clip_fraction        | 0.0973      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.8       |
# |    explained_variance   | -0.257      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0198      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00617    |
# |    std                  | 1           |
# |    value_loss           | 0.0745      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.162       |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 3           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010594906 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.8       |
# |    explained_variance   | 0.0819      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0624      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 1           |
# |    value_loss           | 0.0408      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.321       |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 4           |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012788849 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.8       |
# |    explained_variance   | 0.109       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.016       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 1           |
# |    value_loss           | 0.044       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.333       |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 5           |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012611563 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.8       |
# |    explained_variance   | 0.135       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0404      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.999       |
# |    value_loss           | 0.0723      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12           |
# |    ep_rew_mean          | 0.422        |
# | time/                   |              |
# |    fps                  | 76           |
# |    iterations           | 6            |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0074345055 |
# |    clip_fraction        | 0.0767       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.7        |
# |    explained_variance   | 0.224        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0642       |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00581     |
# |    std                  | 0.996        |
# |    value_loss           | 0.0817       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.338       |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 7           |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009180513 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.7       |
# |    explained_variance   | 0.211       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00485     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0094     |
# |    std                  | 0.995       |
# |    value_loss           | 0.122       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.423       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 8           |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011446338 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.7       |
# |    explained_variance   | 0.158       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00925     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00856    |
# |    std                  | 0.992       |
# |    value_loss           | 0.0782      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.424       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 9           |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011264142 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.7       |
# |    explained_variance   | 0.222       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.034       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.992       |
# |    value_loss           | 0.112       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12         |
# |    ep_rew_mean          | 0.408      |
# | time/                   |            |
# |    fps                  | 75         |
# |    iterations           | 10         |
# |    time_elapsed         | 269        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00901739 |
# |    clip_fraction        | 0.113      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.7      |
# |    explained_variance   | 0.224      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0337     |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.00577   |
# |    std                  | 0.99       |
# |    value_loss           | 0.123      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.362       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 11          |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008742597 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.7       |
# |    explained_variance   | 0.143       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0808      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00527    |
# |    std                  | 0.988       |
# |    value_loss           | 0.246       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.488       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 12          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008561926 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.6       |
# |    explained_variance   | 0.22        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0704      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00539    |
# |    std                  | 0.986       |
# |    value_loss           | 0.123       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12         |
# |    ep_rew_mean          | 0.526      |
# | time/                   |            |
# |    fps                  | 75         |
# |    iterations           | 13         |
# |    time_elapsed         | 351        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.00960287 |
# |    clip_fraction        | 0.0945     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.6      |
# |    explained_variance   | 0.213      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.125      |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.00857   |
# |    std                  | 0.985      |
# |    value_loss           | 0.231      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.537       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 14          |
# |    time_elapsed         | 378         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009469379 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.6       |
# |    explained_variance   | 0.278       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.217       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00661    |
# |    std                  | 0.981       |
# |    value_loss           | 0.17        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12           |
# |    ep_rew_mean          | 0.43         |
# | time/                   |              |
# |    fps                  | 75           |
# |    iterations           | 15           |
# |    time_elapsed         | 405          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0069504925 |
# |    clip_fraction        | 0.0955       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.6        |
# |    explained_variance   | 0.274        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.102        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0053      |
# |    std                  | 0.981        |
# |    value_loss           | 0.232        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.439       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 16          |
# |    time_elapsed         | 432         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008982577 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.6       |
# |    explained_variance   | 0.3         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0125      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00628    |
# |    std                  | 0.979       |
# |    value_loss           | 0.134       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.641       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 17          |
# |    time_elapsed         | 459         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009480418 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.6       |
# |    explained_variance   | 0.286       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.225       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00648    |
# |    std                  | 0.978       |
# |    value_loss           | 0.245       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.676       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 18          |
# |    time_elapsed         | 486         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008844908 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.5       |
# |    explained_variance   | 0.344       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0908      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00434    |
# |    std                  | 0.974       |
# |    value_loss           | 0.181       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.556       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 19          |
# |    time_elapsed         | 513         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.012755064 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.5       |
# |    explained_variance   | 0.307       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0936      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00837    |
# |    std                  | 0.972       |
# |    value_loss           | 0.236       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.567       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 20          |
# |    time_elapsed         | 540         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010438452 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.5       |
# |    explained_variance   | 0.362       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.138       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00256    |
# |    std                  | 0.971       |
# |    value_loss           | 0.257       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.669       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 21          |
# |    time_elapsed         | 567         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009487113 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.5       |
# |    explained_variance   | 0.448       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0139      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00488    |
# |    std                  | 0.969       |
# |    value_loss           | 0.168       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.639       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 22          |
# |    time_elapsed         | 594         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.006746521 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.5       |
# |    explained_variance   | 0.409       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.107       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00454    |
# |    std                  | 0.968       |
# |    value_loss           | 0.302       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.611       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 23          |
# |    time_elapsed         | 621         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.012767049 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.5       |
# |    explained_variance   | 0.424       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.137       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00444    |
# |    std                  | 0.966       |
# |    value_loss           | 0.315       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12           |
# |    ep_rew_mean          | 0.935        |
# | time/                   |              |
# |    fps                  | 75           |
# |    iterations           | 24           |
# |    time_elapsed         | 648          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0071638343 |
# |    clip_fraction        | 0.136        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.5        |
# |    explained_variance   | 0.554        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.113        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00295     |
# |    std                  | 0.967        |
# |    value_loss           | 0.187        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.737       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 25          |
# |    time_elapsed         | 675         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014020421 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.5       |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.262       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00361    |
# |    std                  | 0.967       |
# |    value_loss           | 0.276       |
# -----------------------------------------
# Logging to logs/PPO1_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 0.63     |
# | time/              |          |
# |    fps             | 77       |
# |    iterations      | 1        |
# |    time_elapsed    | 26       |
# |    total_timesteps | 53248    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.656       |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 2           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.018574148 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 0.493       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.308       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00623    |
# |    std                  | 0.963       |
# |    value_loss           | 0.306       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.663       |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 3           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009551415 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 0.536       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0914      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00289    |
# |    std                  | 0.964       |
# |    value_loss           | 0.291       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.74        |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 4           |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.007818941 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0206      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00171    |
# |    std                  | 0.959       |
# |    value_loss           | 0.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.772       |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 5           |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.006029619 |
# |    clip_fraction        | 0.0908      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 0.557       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.437       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00257    |
# |    std                  | 0.957       |
# |    value_loss           | 0.319       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12         |
# |    ep_rew_mean          | 0.634      |
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 6          |
# |    time_elapsed         | 161        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.01804322 |
# |    clip_fraction        | 0.145      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.4      |
# |    explained_variance   | 0.588      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0429     |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.00162   |
# |    std                  | 0.956      |
# |    value_loss           | 0.218      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.786       |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 7           |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.007174275 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 0.584       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.116       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.000842    |
# |    std                  | 0.954       |
# |    value_loss           | 0.215       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.868       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 8           |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.019303603 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 0.554       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.119       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00462    |
# |    std                  | 0.953       |
# |    value_loss           | 0.362       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12           |
# |    ep_rew_mean          | 0.869        |
# | time/                   |              |
# |    fps                  | 75           |
# |    iterations           | 9            |
# |    time_elapsed         | 242          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0087409355 |
# |    clip_fraction        | 0.182        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.3        |
# |    explained_variance   | 0.601        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.164        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | 0.000917     |
# |    std                  | 0.95         |
# |    value_loss           | 0.29         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.854       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 10          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.008918146 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 0.577       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.191       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.000495   |
# |    std                  | 0.946       |
# |    value_loss           | 0.387       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.68        |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 11          |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.018276192 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 0.551       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.324       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00563    |
# |    std                  | 0.947       |
# |    value_loss           | 0.489       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 1.04        |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 12          |
# |    time_elapsed         | 323         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.009036562 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 0.594       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0596      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 1.02e-05    |
# |    std                  | 0.945       |
# |    value_loss           | 0.327       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.984       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 13          |
# |    time_elapsed         | 350         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.009935678 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.2       |
# |    explained_variance   | 0.6         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.105       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00389    |
# |    std                  | 0.94        |
# |    value_loss           | 0.392       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.974       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 14          |
# |    time_elapsed         | 377         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.014934105 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.2       |
# |    explained_variance   | 0.621       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.199       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.000206    |
# |    std                  | 0.943       |
# |    value_loss           | 0.348       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.934       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 15          |
# |    time_elapsed         | 404         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.007455865 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.2       |
# |    explained_variance   | 0.631       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.217       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.00258     |
# |    std                  | 0.946       |
# |    value_loss           | 0.339       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.779       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 16          |
# |    time_elapsed         | 432         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.008342171 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 0.594       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.293       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.000817   |
# |    std                  | 0.948       |
# |    value_loss           | 0.472       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.878       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 17          |
# |    time_elapsed         | 459         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.011989381 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 0.664       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.146       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.000275    |
# |    std                  | 0.949       |
# |    value_loss           | 0.239       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.781       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 18          |
# |    time_elapsed         | 486         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.013896026 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 0.636       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.149       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00173     |
# |    std                  | 0.95        |
# |    value_loss           | 0.298       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12         |
# |    ep_rew_mean          | 0.922      |
# | time/                   |            |
# |    fps                  | 75         |
# |    iterations           | 19         |
# |    time_elapsed         | 513        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.03817088 |
# |    clip_fraction        | 0.207      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.3      |
# |    explained_variance   | 0.62       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0587     |
# |    n_updates            | 430        |
# |    policy_gradient_loss | 0.00168    |
# |    std                  | 0.95       |
# |    value_loss           | 0.365      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.78        |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 20          |
# |    time_elapsed         | 540         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.010362592 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 0.631       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.343       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.000867    |
# |    std                  | 0.947       |
# |    value_loss           | 0.365       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.893       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 21          |
# |    time_elapsed         | 567         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.014724333 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 0.626       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0941      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.000155    |
# |    std                  | 0.943       |
# |    value_loss           | 0.302       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.89        |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 22          |
# |    time_elapsed         | 594         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.014754466 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.2       |
# |    explained_variance   | 0.639       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.058       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.000378    |
# |    std                  | 0.944       |
# |    value_loss           | 0.293       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.935       |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 23          |
# |    time_elapsed         | 621         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010010951 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.2       |
# |    explained_variance   | 0.658       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.18        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.00125     |
# |    std                  | 0.944       |
# |    value_loss           | 0.34        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.74        |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 24          |
# |    time_elapsed         | 648         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.010289524 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.2       |
# |    explained_variance   | 0.658       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.227       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00151     |
# |    std                  | 0.939       |
# |    value_loss           | 0.342       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 25          |
# |    time_elapsed         | 675         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.009056909 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.2       |
# |    explained_variance   | 0.631       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0894      |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0012     |
# |    std                  | 0.937       |
# |    value_loss           | 0.434       |
# -----------------------------------------
# Logging to logs/PPO1_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 0.628    |
# | time/              |          |
# |    fps             | 77       |
# |    iterations      | 1        |
# |    time_elapsed    | 26       |
# |    total_timesteps | 104448   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.825       |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 2           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.019867651 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.1       |
# |    explained_variance   | 0.657       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0464      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.00153     |
# |    std                  | 0.933       |
# |    value_loss           | 0.219       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 1.08        |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 3           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.018874463 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.1       |
# |    explained_variance   | 0.607       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0742      |
# |    n_updates            | 520         |
# |    policy_gradient_loss | 0.0028      |
# |    std                  | 0.931       |
# |    value_loss           | 0.321       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12         |
# |    ep_rew_mean          | 0.716      |
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 4          |
# |    time_elapsed         | 107        |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.01632832 |
# |    clip_fraction        | 0.191      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.1      |
# |    explained_variance   | 0.616      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.112      |
# ...
# |    ep_rew_mean          | 1.54         |
# | time/                   |              |
# |    fps                  | 75           |
# |    iterations           | 21           |
# |    time_elapsed         | 566          |
# |    total_timesteps      | 913408       |
# | train/                  |              |
# |    approx_kl            | 0.0077580474 |
# |    clip_fraction        | 0.172        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.51        |
# |    explained_variance   | 0.725        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.217        |
# |    n_updates            | 4450         |
# |    policy_gradient_loss | 0.000452     |
# |    std                  | 0.716        |
# |    value_loss           | 0.425        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 1.38        |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 22          |
# |    time_elapsed         | 593         |
# |    total_timesteps      | 915456      |
# | train/                  |             |
# |    approx_kl            | 0.027143348 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.49       |
# |    explained_variance   | 0.741       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.178       |
# |    n_updates            | 4460        |
# |    policy_gradient_loss | 0.00366     |
# |    std                  | 0.715       |
# |    value_loss           | 0.68        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 1.19        |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 23          |
# |    time_elapsed         | 620         |
# |    total_timesteps      | 917504      |
# | train/                  |             |
# |    approx_kl            | 0.011960005 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.47       |
# |    explained_variance   | 0.712       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.216       |
# |    n_updates            | 4470        |
# |    policy_gradient_loss | 0.00248     |
# |    std                  | 0.714       |
# |    value_loss           | 0.723       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 1.5         |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 24          |
# |    time_elapsed         | 647         |
# |    total_timesteps      | 919552      |
# | train/                  |             |
# |    approx_kl            | 0.019926818 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.45       |
# |    explained_variance   | 0.713       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.245       |
# |    n_updates            | 4480        |
# |    policy_gradient_loss | 0.0064      |
# |    std                  | 0.711       |
# |    value_loss           | 0.615       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 1.34        |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 25          |
# |    time_elapsed         | 674         |
# |    total_timesteps      | 921600      |
# | train/                  |             |
# |    approx_kl            | 0.024926513 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.43       |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.211       |
# |    n_updates            | 4490        |
# |    policy_gradient_loss | 0.00299     |
# |    std                  | 0.711       |
# |    value_loss           | 0.694       |
# -----------------------------------------
# Logging to logs/PPO1_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 0.974    |
# | time/              |          |
# |    fps             | 78       |
# |    iterations      | 1        |
# |    time_elapsed    | 26       |
# |    total_timesteps | 923648   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 1.01        |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 2           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 925696      |
# | train/                  |             |
# |    approx_kl            | 0.042049423 |
# |    clip_fraction        | 0.281       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.43       |
# |    explained_variance   | 0.747       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0576      |
# |    n_updates            | 4510        |
# |    policy_gradient_loss | 0.00491     |
# |    std                  | 0.712       |
# |    value_loss           | 0.497       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 1.37        |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 3           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 927744      |
# | train/                  |             |
# |    approx_kl            | 0.019202681 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.44       |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.211       |
# |    n_updates            | 4520        |
# |    policy_gradient_loss | 0.0102      |
# |    std                  | 0.712       |
# |    value_loss           | 0.598       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 1.4         |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 4           |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 929792      |
# | train/                  |             |
# |    approx_kl            | 0.008713222 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.44       |
# |    explained_variance   | 0.738       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04        |
# |    n_updates            | 4530        |
# |    policy_gradient_loss | 0.000927    |
# |    std                  | 0.712       |
# |    value_loss           | 0.773       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 1.55        |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 5           |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 931840      |
# | train/                  |             |
# |    approx_kl            | 0.014701158 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.43       |
# |    explained_variance   | 0.728       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.403       |
# |    n_updates            | 4540        |
# |    policy_gradient_loss | 0.000569    |
# |    std                  | 0.712       |
# |    value_loss           | 0.853       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 1.23        |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 6           |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 933888      |
# | train/                  |             |
# |    approx_kl            | 0.029041365 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.45       |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.106       |
# |    n_updates            | 4550        |
# |    policy_gradient_loss | 0.00187     |
# |    std                  | 0.714       |
# |    value_loss           | 0.628       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12           |
# |    ep_rew_mean          | 1.63         |
# | time/                   |              |
# |    fps                  | 76           |
# |    iterations           | 7            |
# |    time_elapsed         | 188          |
# |    total_timesteps      | 935936       |
# | train/                  |              |
# |    approx_kl            | 0.0071067363 |
# |    clip_fraction        | 0.184        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.45        |
# |    explained_variance   | 0.689        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.209        |
# |    n_updates            | 4560         |
# |    policy_gradient_loss | 0.00141      |
# |    std                  | 0.714        |
# |    value_loss           | 0.485        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 1.31        |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 8           |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 937984      |
# | train/                  |             |
# |    approx_kl            | 0.014251771 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.44       |
# |    explained_variance   | 0.75        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0705      |
# |    n_updates            | 4570        |
# |    policy_gradient_loss | 0.00411     |
# |    std                  | 0.714       |
# |    value_loss           | 0.766       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 1.31        |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 9           |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 940032      |
# | train/                  |             |
# |    approx_kl            | 0.010672398 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.45       |
# |    explained_variance   | 0.722       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.238       |
# |    n_updates            | 4580        |
# |    policy_gradient_loss | -0.0027     |
# |    std                  | 0.714       |
# |    value_loss           | 0.844       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 1.24        |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 10          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 942080      |
# | train/                  |             |
# |    approx_kl            | 0.018733498 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.44       |
# |    explained_variance   | 0.72        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.465       |
# |    n_updates            | 4590        |
# |    policy_gradient_loss | 0.00688     |
# |    std                  | 0.713       |
# |    value_loss           | 0.586       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12         |
# |    ep_rew_mean          | 1.26       |
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 11         |
# |    time_elapsed         | 296        |
# |    total_timesteps      | 944128     |
# | train/                  |            |
# |    approx_kl            | 0.01574119 |
# |    clip_fraction        | 0.249      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.43      |
# |    explained_variance   | 0.666      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.19       |
# |    n_updates            | 4600       |
# |    policy_gradient_loss | 0.00207    |
# |    std                  | 0.711      |
# |    value_loss           | 0.576      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12           |
# |    ep_rew_mean          | 1.08         |
# | time/                   |              |
# |    fps                  | 75           |
# |    iterations           | 12           |
# |    time_elapsed         | 323          |
# |    total_timesteps      | 946176       |
# | train/                  |              |
# |    approx_kl            | 0.0074298535 |
# |    clip_fraction        | 0.248        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.43        |
# |    explained_variance   | 0.727        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.473        |
# |    n_updates            | 4610         |
# |    policy_gradient_loss | 0.00303      |
# |    std                  | 0.713        |
# |    value_loss           | 0.565        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12         |
# |    ep_rew_mean          | 1.31       |
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 13         |
# |    time_elapsed         | 350        |
# |    total_timesteps      | 948224     |
# | train/                  |            |
# |    approx_kl            | 0.05910369 |
# |    clip_fraction        | 0.232      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.43      |
# |    explained_variance   | 0.718      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.389      |
# |    n_updates            | 4620       |
# |    policy_gradient_loss | 0.00856    |
# |    std                  | 0.712      |
# |    value_loss           | 0.453      |
# ----------------------------------------

# %%
for _ in range(10):
    obs = env.reset()
    done = False
    while not done:
        env.render()
        obs, reward, done, info = env.step(env.action_space.sample())

# %%
obs = env.reset()

# %%
obs, reward, done, info = env.step(env.action_space.sample())
print(obs)
print(reward)
# Out:
# [1.7070101e+01 1.6412806e-02 2.8751437e+02]
# 1.000000002699536
