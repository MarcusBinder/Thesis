# %% [markdown]
# # Plots for the introduction
#
# To help keep a consisten feel of plots and so on, this document will do any plots used.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Source is:
# https://ec.europa.eu/commission/presscorner/detail/en/ip_20_2096

year = np.array(["2021", "2030", "2050"])
gw = np.array([12, 60, 300])
gw_text = np.array(["12GW", "60GW", "300GW"])
gw_test = np.array(["60GW", "120GW","180GW","240GW","300GW"])
gw1 = np.array([60, 120, 180, 240, 300])

fig = plt.gcf()
fig.set_size_inches(15, 7)
ax = plt.gca()


plt.bar(year, gw, width=0.5)


#plt.xlabel("Year", fontsize = 12, fontweight="bold")
#plt.ylabel("Energy production [GW]", fontsize = 12, fontweight="bold")
plt.title("Offshore wind energy production in the European Union", fontsize = 12, fontweight="bold")
plt.yticks(gw1, gw_test, fontsize = 12, fontweight = "bold")
plt.xticks(fontsize = 12, fontweight = "bold")

plt.show()
fig.savefig('kap1/Energy_prod.png', dpi=150)

# %%
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

Report = ["IRENA - Roadmap to 2050 1.5 Degree Celsius Scenario",
          "IEA - Sustainable development scenario - Global",
          "UK CCC, Balanced Pathway - UK"]
Solar =       np.array([25, 20, 14])
Hydro =       np.array([14, 6, 0])
Nuclear =     np.array([5, 11, 6])
Non_renew =   np.array([9, 22, 8])
Bioenergy =   np.array([7, 19, 3])
Wind =        np.array([34, 16, 70])
Other_renew = np.array([6, 6, 0])



b1 = plt.barh(Report, Solar, color="red")
b2 = plt.barh(Report, Hydro, left=(Solar))
b3 = plt.barh(Report, Nuclear, left=(Solar+Hydro))
b4 = plt.barh(Report, Non_renew, left=Nuclear+Solar+Hydro)
b5 = plt.barh(Report, Bioenergy, left=Non_renew+Nuclear+Solar+Hydro)
b6 = plt.barh(Report, Wind, left=Bioenergy+Non_renew+Nuclear+Solar+Hydro)
b7 = plt.barh(Report, Other_renew, left=Wind+Bioenergy+Non_renew+Nuclear+Solar+Hydro)

plt.legend([b1, b2, b3, b4, b5, b6, b7], ["Solar", "Hydro", "Nuclear",
                                          "Non Renewable", "Bioenergy", "Wind", "Other renewable"], title="Sources", loc="upper right")

plt.show()

# %%
Solar + Hydrocu
# Out:
# [25, 20, 14, 14, 6, 0]
