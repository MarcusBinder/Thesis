# %%
import gym
import numpy as np
from stable_baselines3 import A2C, DDPG, SAC, PPO
from matplotlib import axis
import numpy as np
from floris.tools import FlorisInterface
from floris.tools.visualization import visualize_cut_plane
import matplotlib.pyplot as plt
from floris.tools.optimization.yaw_optimization.yaw_optimizer_sr import YawOptimizationSR

from gym import spaces

from stable_baselines3.common.env_checker import check_env
import os
import time
from tqdm import tqdm_notebook
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.callbacks import BaseCallback

from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.utils import set_random_seed

from matplotlib.pyplot import figure

#loading optimization package:
from scipy.optimize import minimize

from floris.tools.optimization.yaw_optimization.yaw_optimizer_scipy import (
    YawOptimizationScipy
)

from time import perf_counter as timerpc

import yaml
import math
from scipy import interpolate
import random

# %%
class CustomEnv(gym.Env):
    """
    The inputs are:
    t_steps     = number of timesteps pr simulation
    dist        ª= rotor diameters between the turbines
    nx          = number of turbines along x axis
    ny          = number of turbines along y axis
    turb_type   = The type of turbine used for the environment
    combination = The combination model
    deflection  = The deflection model
    turbulence  = The turbulence model
    velocity    = The wake velocity model
    VS_min      = minimum wind speed [m/s]
    VS_max      = maximum wind speed [m/s]
    TI_min      = minimum turbulence intensity
    TI_max      = maximum turbulence intensity
    wd_min      = minimum wind direction
    wd_max      = maximum wind direction
    yaw_max     = Is the maximum yaw offset allowed in degrees.
    
    """
    #Custom Environment that follows gym interface
    metadata = {'render.modes': ['human']}

    def __init__(self, t_steps = 10, dist = 5, nx = 3, ny = 3,
               turb_type = 'nrel_5MW', combination = 'sosfs', deflection = 'gauss',
               turbulence = 'crespo_hernandez', velocity = 'gauss',
               VS_min = 4, VS_max = 20, TI_min = 0.01, TI_max = 0.15, wd_min = 270, wd_max = 360, 
               yaw_max = 25, rho = 1.225, seed = 0):
        super(CustomEnv, self).__init__()
        
        random.seed(seed)
        np.random.seed(seed)
        
        self.t_max = t_steps   #The number of "simulations" pr episode.
        self.wind_speed_min = VS_min
        self.wind_speed_max = VS_max
        self.TI_min         = TI_min
        self.TI_max         = TI_max
        self.wd_min         = wd_min
        self.wd_max         = wd_max
        self.n_turb         = nx * ny
        self.yaw_max        = yaw_max
        self.rho            = rho
                     
        #Creates the base for the farm
        fi = FlorisInterface("gch.yaml")   
        
        #Turns it into a dictionary and then does the changes to the model
        fi_dict = fi.floris.as_dict()
        
        fi_dict["farm"]["turbine_type"] = [turb_type]
        fi_dict["wake"]["model_strings"]["combination_model"] = combination
        fi_dict["wake"]["model_strings"]["deflection_model"]  = deflection
        fi_dict["wake"]["model_strings"]["turbulence_model"]  = turbulence
        fi_dict["wake"]["model_strings"]["velocity_model"]    = velocity
        fi_dict["flow_field"]["air_density"]                  = rho
        
        # Turns it back into a floris object:
        self.fi = FlorisInterface(fi_dict)

        D = self.fi.floris.farm.rotor_diameters[0]

        x = np.linspace(0, D*dist*nx, nx)
        y = np.linspace(0, D*dist*ny, ny)

        xv, yv = np.meshgrid(x, y, indexing='xy')
        
        self.layout_x =  xv.flatten()
        self.layout_y = yv.flatten()
        
        #Reads and saves the power curve for one turbine:
        
        with open(turb_type+".yaml", 'r') as stream:
            try:
                parsed_yaml=yaml.safe_load(stream)
                #print(parsed_yaml)
            except yaml.YAMLError as exc:
                print(exc)

        ws_curve = parsed_yaml["power_thrust_table"]["wind_speed"]
        power_curve = parsed_yaml["power_thrust_table"]["power"]
        
        self.A = 3.14 * (D/2)**2
        self.power_curve = interpolate.interp1d(ws_curve, power_curve)
        

        # Define action and observation space
        
        # The actionspace is the 9 yaw angles.
        self.action_space = spaces.Box(low=-1, high=1,
                                            shape=(nx*ny,), dtype=np.float32)
        
        # The observationspace is WS, TI, WD:
        high = np.array([self.wind_speed_max, self.TI_max, self.wd_max], dtype = np.float32)
        low = np.array([self.wind_speed_min, self.TI_min, self.wd_min], dtype = np.float32)
        
        self.observation_space = spaces.Box(low, high, dtype=np.float32)

        self.reset()
        
    def step(self, action):
        #print("we did a step")
        if self.time > self.t_max:
            done =  True
        else:
            self.time += 1
            done = False
            
        self.fi.calculate_wake(yaw_angles=np.array([[action]]))  #weird format, but it's okay
        
        power_farm = self.fi.get_farm_power()
        
        #Choose if you want ideal farm, or greedy farm for reward calculation.
        #rew = self.fi.get_farm_power()/self.power_ideal_farm
        rew = self.fi.get_farm_power()/self.power_greey_farm
        
        reward = (rew[0][0]-1)*1000   
            
        info = {}
        observation = np.array([self.ws, self.TI, self.wd], dtype = np.float32)
        return observation, reward, done, info
    
    def reset(self):
        
        #
        self.ws = np.random.uniform(self.wind_speed_min, self.wind_speed_max)
        self.wd = np.random.uniform(self.wd_min, self.wd_max)
        self.TI = np.random.uniform(self.TI_min, self.TI_max)
        

        
        self.fi.reinitialize(
            layout=(self.layout_x, self.layout_y),
            wind_directions=[self.wd],
            turbulence_intensity= self.TI,
            wind_speeds=[self.ws]
            )
        
        
        #Calculate greedy power. Used for normalization
        self.fi.calculate_wake()
        self.power_greey_farm = self.fi.get_farm_power()
        
        #calculate the power for the ideal farm. Used for normalization
        self.power_ideal_farm = self.power_curve(self.ws)*self.n_turb* (1/2) * self.rho * self.A * self.ws**3
        
        self.time = 0
        done = False
        
        observation = np.array([self.ws, self.TI, self.wd], dtype = np.float32)
        return observation  # reward, done, info can't be included
    
    def render(self, mode='human'):
        pass
    
    def close (self):
        pass

# %%
model_name = "PPO3"
SEED = 0

# %%
env = CustomEnv(t_steps = 10, dist = 5, nx = 3, ny = 3,
               turb_type = 'nrel_5MW', combination = 'sosfs', deflection = 'gauss',
               turbulence = 'crespo_hernandez', velocity = 'gauss',
               VS_min = 4, VS_max = 15, TI_min = 0.07, TI_max = 0.07, wd_min = 270, wd_max = 315, 
               yaw_max = 25, rho = 1.225, seed = SEED)
check_env(env)

# %%
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log='logs', seed = SEED)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
models_dir = "models/"+model_name
log_dir = "logs"

if not os.path.exists(models_dir):
    os.makedirs(models_dir)
    
if not os.path.exists(log_dir):
    os.makedirs(log_dir)

# %%
TIMESTEPS = 20_000

for i in range(1,50):
    model.learn(total_timesteps = TIMESTEPS, reset_num_timesteps = False, tb_log_name=model_name)
    model.save(f"{models_dir}/{TIMESTEPS*i}")
# Out:
# Logging to logs/PPO3_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | -0.554   |
# | time/              |          |
# |    fps             | 73       |
# |    iterations      | 1        |
# |    time_elapsed    | 27       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | -0.638      |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 2           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010051884 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.8       |
# |    explained_variance   | 0.00356     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.86        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.999       |
# |    value_loss           | 3.91        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | -0.676      |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 3           |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011777869 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.7       |
# |    explained_variance   | 0.0267      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.52        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00826    |
# |    std                  | 0.991       |
# |    value_loss           | 4.35        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.241       |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 4           |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007974478 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.6       |
# |    explained_variance   | 0.00347     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.42        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.983       |
# |    value_loss           | 6.5         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.742       |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 5           |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009174807 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.6       |
# |    explained_variance   | -0.00219    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.04        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00661    |
# |    std                  | 0.979       |
# |    value_loss           | 5.53        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.466       |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 6           |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007830154 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.6       |
# |    explained_variance   | 0.00491     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.6         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00679    |
# |    std                  | 0.975       |
# |    value_loss           | 11.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.812       |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 7           |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008494989 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.5       |
# |    explained_variance   | 0.00676     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.24        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00509    |
# |    std                  | 0.973       |
# |    value_loss           | 9.87        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.677       |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 8           |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008177869 |
# |    clip_fraction        | 0.0978      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.5       |
# |    explained_variance   | 0.00609     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.85        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00842    |
# |    std                  | 0.972       |
# |    value_loss           | 11.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 1.21        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 9           |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011750415 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.5       |
# |    explained_variance   | 0.0194      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.95        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00854    |
# |    std                  | 0.969       |
# |    value_loss           | 10.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 1.55        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 10          |
# |    time_elapsed         | 283         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010555098 |
# |    clip_fraction        | 0.0876      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.5       |
# |    explained_variance   | 0.00615     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.08        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00516    |
# |    std                  | 0.967       |
# |    value_loss           | 13.3        |
# -----------------------------------------
# Logging to logs/PPO3_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 0.254    |
# | time/              |          |
# |    fps             | 73       |
# |    iterations      | 1        |
# |    time_elapsed    | 27       |
# |    total_timesteps | 22528    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 3.52        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 2           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.014316825 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.5       |
# |    explained_variance   | 0.00626     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.4         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00548    |
# |    std                  | 0.966       |
# |    value_loss           | 15.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12           |
# |    ep_rew_mean          | 3.22         |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 3            |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0111892875 |
# |    clip_fraction        | 0.106        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.4        |
# |    explained_variance   | 0.0339       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.49         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00864     |
# |    std                  | 0.964        |
# |    value_loss           | 25.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.917       |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 4           |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.013344309 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 0.024       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.42        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00703    |
# |    std                  | 0.963       |
# |    value_loss           | 24.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12           |
# |    ep_rew_mean          | 3.49         |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 5            |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0057307174 |
# |    clip_fraction        | 0.0819       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.4        |
# |    explained_variance   | 0.0466       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.02         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00574     |
# |    std                  | 0.964        |
# |    value_loss           | 18.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 2.12        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 6           |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009586356 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 0.0375      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.48        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00559    |
# |    std                  | 0.964       |
# |    value_loss           | 39.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.419       |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 7           |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.005124907 |
# |    clip_fraction        | 0.0331      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 0.0573      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.2        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00335    |
# |    std                  | 0.963       |
# |    value_loss           | 35.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 1.2         |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 8           |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004908867 |
# |    clip_fraction        | 0.0905      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 0.0732      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.2        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00383    |
# |    std                  | 0.962       |
# |    value_loss           | 26.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 2.95        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 9           |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010339649 |
# |    clip_fraction        | 0.0776      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 0.0808      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.4        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00344    |
# |    std                  | 0.961       |
# |    value_loss           | 27.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 5.2         |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 10          |
# |    time_elapsed         | 283         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006734922 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 0.1         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.7        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0037     |
# |    std                  | 0.96        |
# |    value_loss           | 31.2        |
# -----------------------------------------
# Logging to logs/PPO3_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 2.79     |
# | time/              |          |
# |    fps             | 74       |
# |    iterations      | 1        |
# |    time_elapsed    | 27       |
# |    total_timesteps | 43008    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 3.43        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 2           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009394087 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 0.126       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.5        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00368    |
# |    std                  | 0.959       |
# |    value_loss           | 48.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 3.81        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 3           |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.033616547 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 0.129       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.9        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0022     |
# |    std                  | 0.959       |
# |    value_loss           | 51.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 4.39        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 4           |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.011835509 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 0.151       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.3        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00521    |
# |    std                  | 0.957       |
# |    value_loss           | 48.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 2.44        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 5           |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010318911 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 0.167       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.3        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00176    |
# |    std                  | 0.958       |
# |    value_loss           | 52.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 0.589       |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 6           |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.008223364 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 0.199       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.1        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00426    |
# |    std                  | 0.957       |
# |    value_loss           | 40.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 3.37        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 7           |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.010494514 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 0.223       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.69        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.00196     |
# |    std                  | 0.957       |
# |    value_loss           | 31.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 4.35        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 8           |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010699179 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 0.227       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.5        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00278    |
# |    std                  | 0.955       |
# |    value_loss           | 43.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12           |
# |    ep_rew_mean          | 3.44         |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 9            |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0086881835 |
# |    clip_fraction        | 0.276        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.4        |
# |    explained_variance   | 0.257        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.5         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | 0.0155       |
# |    std                  | 0.955        |
# |    value_loss           | 64.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 2.7         |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 10          |
# |    time_elapsed         | 283         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.019070972 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 0.287       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.5        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.0098      |
# |    std                  | 0.954       |
# |    value_loss           | 43          |
# -----------------------------------------
# Logging to logs/PPO3_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 2.11     |
# | time/              |          |
# |    fps             | 74       |
# |    iterations      | 1        |
# |    time_elapsed    | 27       |
# |    total_timesteps | 63488    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 4.85        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 2           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.007948115 |
# |    clip_fraction        | 0.0991      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 0.305       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.6        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.000756   |
# |    std                  | 0.954       |
# |    value_loss           | 50.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 3.37        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 3           |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.010260714 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 0.318       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.6        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00691     |
# |    std                  | 0.952       |
# |    value_loss           | 55.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12           |
# |    ep_rew_mean          | 2.03         |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 4            |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0061094174 |
# |    clip_fraction        | 0.127        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.3        |
# |    explained_variance   | 0.335        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.6         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000868    |
# |    std                  | 0.952        |
# |    value_loss           | 40.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 2.52        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 5           |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.058391266 |
# |    clip_fraction        | 0.422       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 0.292       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.4        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.0279      |
# |    std                  | 0.949       |
# |    value_loss           | 62.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 6.81        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 6           |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.010918385 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 0.338       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.2        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.00265     |
# |    std                  | 0.949       |
# |    value_loss           | 47.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 3.69        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 7           |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.006336222 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 0.298       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 65.3        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00238     |
# |    std                  | 0.948       |
# |    value_loss           | 98.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12         |
# |    ep_rew_mean          | 4.63       |
# | time/                   |            |
# |    fps                  | 72         |
# |    iterations           | 8          |
# |    time_elapsed         | 226        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.01716097 |
# |    clip_fraction        | 0.189      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.3      |
# |    explained_variance   | 0.328      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.41       |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0024    |
# |    std                  | 0.947      |
# |    value_loss           | 70.6       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12           |
# |    ep_rew_mean          | 9.14         |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 9            |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0074693076 |
# |    clip_fraction        | 0.0721       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.3        |
# |    explained_variance   | 0.335        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.4         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00365     |
# |    std                  | 0.947        |
# |    value_loss           | 73.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12           |
# |    ep_rew_mean          | 3.5          |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 10           |
# |    time_elapsed         | 283          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0047163535 |
# |    clip_fraction        | 0.0986       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.3        |
# |    explained_variance   | 0.352        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 91.8         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00193     |
# |    std                  | 0.947        |
# |    value_loss           | 80.1         |
# ------------------------------------------
# Logging to logs/PPO3_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 2.47     |
# | time/              |          |
# |    fps             | 74       |
# |    iterations      | 1        |
# |    time_elapsed    | 27       |
# |    total_timesteps | 83968    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 7.25        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 2           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.011325892 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 0.371       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.2        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00192    |
# |    std                  | 0.946       |
# |    value_loss           | 43.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 6.01        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 3           |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.010719152 |
# |    clip_fraction        | 0.0869      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 0.377       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.9        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00403    |
# |    std                  | 0.945       |
# |    value_loss           | 70.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 3.68        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 4           |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.010167117 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 0.379       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.3        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00101    |
# |    std                  | 0.945       |
# |    value_loss           | 62.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12         |
# |    ep_rew_mean          | 4.88       |
# | time/                   |            |
# |    fps                  | 72         |
# |    iterations           | 5          |
# |    time_elapsed         | 141        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.00737725 |
# |    clip_fraction        | 0.0961     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.2      |
# |    explained_variance   | 0.421      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21.9       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | 0.000241   |
# |    std                  | 0.944      |
# |    value_loss           | 54.9       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12           |
# |    ep_rew_mean          | 4.77         |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 6            |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0071561458 |
# |    clip_fraction        | 0.305        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.2        |
# |    explained_variance   | 0.412        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.6         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | 0.0184       |
# |    std                  | 0.942        |
# |    value_loss           | 75.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 2.41        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 7           |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.011553494 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.2       |
# |    explained_variance   | 0.406       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.2        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.000915   |
# |    std                  | 0.943       |
# |    value_loss           | 56.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12           |
# |    ep_rew_mean          | 2.14         |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 8            |
# |    time_elapsed         | 226          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0080641275 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.2        |
# |    explained_variance   | 0.421        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.8         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | 0.00161      |
# |    std                  | 0.943        |
# |    value_loss           | 36.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 3.94        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 9           |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.014204285 |
# |    clip_fraction        | 0.376       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.2       |
# |    explained_variance   | 0.409       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.5        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.0305      |
# |    std                  | 0.942       |
# |    value_loss           | 45.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 3.16        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 10          |
# |    time_elapsed         | 282         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.007827109 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.2       |
# |    explained_variance   | 0.447       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.4        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00278    |
# |    std                  | 0.94        |
# |    value_loss           | 64.2        |
# -----------------------------------------
# Logging to logs/PPO3_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | -0.0118  |
# | time/              |          |
# |    fps             | 74       |
# |    iterations      | 1        |
# |    time_elapsed    | 27       |
# |    total_timesteps | 104448   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 2.71        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 2           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.012009031 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.2       |
# |    explained_variance   | 0.482       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.5        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.00935     |
# |    std                  | 0.939       |
# |    value_loss           | 58          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 1.65        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 3           |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.010235344 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.2       |
# |    explained_variance   | 0.375       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.3        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | 0.00639     |
# |    std                  | 0.939       |
# |    value_loss           | 60.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 2.25        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 4           |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.008847225 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.2       |
# |    explained_variance   | 0.432       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.8        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.000194   |
# |    std                  | 0.941       |
# |    value_loss           | 50.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 6.84        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 5           |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.013052536 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.2       |
# |    explained_variance   | 0.365       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.8        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | 0.00214     |
# |    std                  | 0.935       |
# |    value_loss           | 36.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 7.81        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 6           |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 114688      |
# ...
# |    explained_variance   | 0.639       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.8        |
# |    n_updates            | 4160        |
# |    policy_gradient_loss | 0.0134      |
# |    std                  | 0.855       |
# |    value_loss           | 87.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 4.28        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 8           |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 856064      |
# | train/                  |             |
# |    approx_kl            | 0.031663157 |
# |    clip_fraction        | 0.639       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 0.637       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 151         |
# |    n_updates            | 4170        |
# |    policy_gradient_loss | 0.0625      |
# |    std                  | 0.856       |
# |    value_loss           | 149         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 8.7         |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 9           |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 858112      |
# | train/                  |             |
# |    approx_kl            | 0.015647737 |
# |    clip_fraction        | 0.0977      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 0.645       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.4        |
# |    n_updates            | 4180        |
# |    policy_gradient_loss | -0.00106    |
# |    std                  | 0.856       |
# |    value_loss           | 96.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12         |
# |    ep_rew_mean          | 5.52       |
# | time/                   |            |
# |    fps                  | 72         |
# |    iterations           | 10         |
# |    time_elapsed         | 283        |
# |    total_timesteps      | 860160     |
# | train/                  |            |
# |    approx_kl            | 0.11374809 |
# |    clip_fraction        | 0.579      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -11.3      |
# |    explained_variance   | 0.581      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 94.2       |
# |    n_updates            | 4190       |
# |    policy_gradient_loss | 0.0675     |
# |    std                  | 0.859      |
# |    value_loss           | 124        |
# ----------------------------------------
# Logging to logs/PPO3_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 8.94     |
# | time/              |          |
# |    fps             | 74       |
# |    iterations      | 1        |
# |    time_elapsed    | 27       |
# |    total_timesteps | 862208   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 9.52        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 2           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 864256      |
# | train/                  |             |
# |    approx_kl            | 0.004649082 |
# |    clip_fraction        | 0.0814      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 0.589       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 84.7        |
# |    n_updates            | 4210        |
# |    policy_gradient_loss | -0.00092    |
# |    std                  | 0.858       |
# |    value_loss           | 136         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12           |
# |    ep_rew_mean          | 6.4          |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 3            |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 866304       |
# | train/                  |              |
# |    approx_kl            | 0.0070100226 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11.3        |
# |    explained_variance   | 0.658        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 72.4         |
# |    n_updates            | 4220         |
# |    policy_gradient_loss | 0.000708     |
# |    std                  | 0.859        |
# |    value_loss           | 121          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12         |
# |    ep_rew_mean          | 5.64       |
# | time/                   |            |
# |    fps                  | 72         |
# |    iterations           | 4          |
# |    time_elapsed         | 112        |
# |    total_timesteps      | 868352     |
# | train/                  |            |
# |    approx_kl            | 0.00559882 |
# |    clip_fraction        | 0.0671     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -11.3      |
# |    explained_variance   | 0.63       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 91.3       |
# |    n_updates            | 4230       |
# |    policy_gradient_loss | -0.0002    |
# |    std                  | 0.858      |
# |    value_loss           | 128        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 2.99        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 5           |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 870400      |
# | train/                  |             |
# |    approx_kl            | 0.007946912 |
# |    clip_fraction        | 0.0515      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 0.636       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.9        |
# |    n_updates            | 4240        |
# |    policy_gradient_loss | -0.00233    |
# |    std                  | 0.859       |
# |    value_loss           | 117         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 2.6         |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 6           |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 872448      |
# | train/                  |             |
# |    approx_kl            | 0.017140545 |
# |    clip_fraction        | 0.318       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 0.508       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.8        |
# |    n_updates            | 4250        |
# |    policy_gradient_loss | 0.0102      |
# |    std                  | 0.858       |
# |    value_loss           | 94.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 9.22        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 7           |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 874496      |
# | train/                  |             |
# |    approx_kl            | 0.012341831 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 0.323       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.8        |
# |    n_updates            | 4260        |
# |    policy_gradient_loss | -0.00305    |
# |    std                  | 0.858       |
# |    value_loss           | 77.3        |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [91], in <cell line: 3>()
#       1 TIMESTEPS = 20_000
#       3 for i in range(1,50):
# ----> 4     model.learn(total_timesteps = TIMESTEPS, reset_num_timesteps = False, tb_log_name="PPO3")
#       5     model.save(f"{models_dir}/{TIMESTEPS*i}")
#
# File ~/anaconda3/envs/thesis/lib/python3.9/site-packages/stable_baselines3/ppo/ppo.py:310, in PPO.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     297 def learn(
#     298     self,
#     299     total_timesteps: int,
#    (...)
#     307     reset_num_timesteps: bool = True,
#     308 ) -> "PPO":
# --> 310     return super().learn(
#     311         total_timesteps=total_timesteps,
#     312         callback=callback,
#     313         log_interval=log_interval,
#     314         eval_env=eval_env,
#     315         eval_freq=eval_freq,
#     316         n_eval_episodes=n_eval_episodes,
#     317         tb_log_name=tb_log_name,
#     318         eval_log_path=eval_log_path,
#     319         reset_num_timesteps=reset_num_timesteps,
#     320     )
#
# File ~/anaconda3/envs/thesis/lib/python3.9/site-packages/stable_baselines3/common/on_policy_algorithm.py:247, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     243 callback.on_training_start(locals(), globals())
#     245 while self.num_timesteps < total_timesteps:
# --> 247     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     249     if continue_training is False:
#     250         break
#
# File ~/anaconda3/envs/thesis/lib/python3.9/site-packages/stable_baselines3/common/on_policy_algorithm.py:175, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     172 if isinstance(self.action_space, gym.spaces.Box):
#     173     clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 175 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     177 self.num_timesteps += env.num_envs
#     179 # Give access to local variables
#
# File ~/anaconda3/envs/thesis/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:162, in VecEnv.step(self, actions)
#     155 """
#     156 Step the environments with the given action
#     157
#     158 :param actions: the action
#     159 :return: observation, reward, done, information
#     160 """
#     161 self.step_async(actions)
# --> 162 return self.step_wait()
#
# File ~/anaconda3/envs/thesis/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:43, in DummyVecEnv.step_wait(self)
#      41 def step_wait(self) -> VecEnvStepReturn:
#      42     for env_idx in range(self.num_envs):
# ---> 43         obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      44             self.actions[env_idx]
#      45         )
#      46         if self.buf_dones[env_idx]:
#      47             # save final observation where user can get it, then reset
#      48             self.buf_infos[env_idx]["terminal_observation"] = obs
#
# File ~/anaconda3/envs/thesis/lib/python3.9/site-packages/stable_baselines3/common/monitor.py:90, in Monitor.step(self, action)
#      88 if self.needs_reset:
#      89     raise RuntimeError("Tried to step environment that needs reset")
# ---> 90 observation, reward, done, info = self.env.step(action)
#      91 self.rewards.append(reward)
#      92 if done:
#
# Input In [39], in CustomEnv.step(self, action)
#     107     self.time += 1
#     108     done = False
# --> 110 self.fi.calculate_wake(yaw_angles=np.array([[action]]))  #weird format, but it's okay
#     112 power_farm = self.fi.get_farm_power()
#     114 #Choose if you want ideal farm, or greedy farm for reward calculation.
#     115 #rew = self.fi.get_farm_power()/self.power_ideal_farm
#
# File ~/floris/floris/tools/floris_interface.py:140, in FlorisInterface.calculate_wake(self, yaw_angles)
#     137 self.floris.initialize_domain()
#     139 # Perform the wake calculations
# --> 140 self.floris.steady_state_atmospheric_condition()
#
# File ~/floris/floris/simulation/floris.py:164, in Floris.steady_state_atmospheric_condition(self)
#     157     elapsed_time = turbopark_solver(
#     158         self.farm,
#     159         self.flow_field,
#     160         self.grid,
#     161         self.wake
#     162     )
#     163 else:
# --> 164     elapsed_time = sequential_solver(
#     165         self.farm,
#     166         self.flow_field,
#     167         self.grid,
#     168         self.wake
#     169     )
#     170 # end = time.time()
#     171 # elapsed_time = end - start
#     173 self.finalize()
#
# File ~/floris/floris/simulation/solver.py:107, in sequential_solver(farm, flow_field, grid, model_manager)
#     104 effective_yaw_i += yaw_angle_i
#     106 if model_manager.enable_secondary_steering:
# --> 107     added_yaw = wake_added_yaw(
#     108         u_i,
#     109         v_i,
#     110         flow_field.u_initial_sorted,
#     111         grid.y_sorted[:, :, i:i+1] - y_i,
#     112         grid.z_sorted[:, :, i:i+1],
#     113         rotor_diameter_i,
#     114         hub_height_i,
#     115         ct_i,
#     116         TSR_i,
#     117         axial_induction_i
#     118     )
#     119     effective_yaw_i += added_yaw
#     121 # Model calculations
#     122 # NOTE: exponential
#
# File ~/floris/floris/simulation/wake_deflection/gauss.py:300, in wake_added_yaw(u_i, v_i, u_initial, delta_y, z_i, rotor_diameter, hub_height, ct_i, tip_speed_ratio, axial_induction_i, scale)
#     291 vel_bottom = ((HH - D / 2) / HH) ** 0.12 * np.ones((1, 1, 1, 1, 1))
#     292 Gamma_bottom = -1 * gamma(
#     293     D,
#     294     vel_bottom,
#    (...)
#     297     scale,
#     298 )
# --> 300 turbine_average_velocity = np.cbrt(np.mean(u_i ** 3, axis=(3,4)))
#     301 turbine_average_velocity = turbine_average_velocity[:,:,:,None,None]
#     302 Gamma_wake_rotation = 0.25 * 2 * np.pi * D * (aI - aI ** 2) * turbine_average_velocity / TSR
#
# File <__array_function__ internals>:180, in mean(*args, **kwargs)
#
# File ~/anaconda3/envs/thesis/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3474, in mean(a, axis, dtype, out, keepdims, where)
#    3471     else:
#    3472         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3474 return _methods._mean(a, axis=axis, dtype=dtype,
#    3475                       out=out, **kwargs)
#
# File ~/anaconda3/envs/thesis/lib/python3.9/site-packages/numpy/core/_methods.py:181, in _mean(a, axis, dtype, out, keepdims, where)
#     179 ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     180 if isinstance(ret, mu.ndarray):
# --> 181     ret = um.true_divide(
#     182             ret, rcount, out=ret, casting='unsafe', subok=False)
#     183     if is_float16_result and out is None:
#     184         ret = arr.dtype.type(ret)
#
# KeyboardInterrupt:

# %%
for _ in range(10):
    obs = env.reset()
    done = False
    while not done:
        env.render()
        obs, reward, done, info = env.step(env.action_space.sample())

# %%
obs = env.reset()

# %%
obs, reward, done, info = env.step(env.action_space.sample())
print(obs)
print(reward)
# Out:
# [1.4739102e+01 7.0000000e-02 2.8011847e+02]
# 2.8876856461579337e-07
